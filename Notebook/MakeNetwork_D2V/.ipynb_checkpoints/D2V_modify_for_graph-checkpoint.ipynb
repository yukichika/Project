# %%
import os
import cPickle as pickle
import configparser
import codecs
from distutils.util import strtobool
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

import sys
sys.path.append("../../MyPythonModule")
import mymodule
sys.path.append("../../Interactive_Graph_Visualizer/networkx-master")
import networkx as nx

# %%
def cos_sim(v1, v2):
    return np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))

# %%
def suffix_generator_root(search_word,max_page,add_childs,append):
    suffix = "_" + search_word
    suffix += "_" + unicode(max_page)
    if add_childs:
        suffix += "_add_childs"
    if append:
        suffix += "_append"
    return suffix

# %%
def suffix_generator(target=None,is_largest=False):
    suffix = ""
    if target != None:
        suffix += "_" + target
    if is_largest == True:
        suffix += "_largest"
    return suffix

# %%
search_word = "Test"
max_page = 10
add_childs = True
append = False
save_dir = "../Data/Search"
root_dir = save_dir + suffix_generator_root(search_word,max_page,add_childs,append)

is_largest = True
target = "myexttext"
K = 10
exp_name = "K" + unicode(K) + suffix_generator(target,is_largest)
exp_dir = os.path.join(root_dir,exp_name)
nx_dir = os.path.join(exp_dir,"nx_datas")

size = 100
exp_name_new = "D" + str(size) + suffix_generator(target,is_largest)
exp_dir_new = os.path.join(root_dir,exp_name_new)
nx_dir_new = os.path.join(exp_dir_new,"nx_datas")

# %%
if not os.path.exists(nx_dir_new):
    os.mkdir(nx_dir_new)

# %%
weights_list = []
comp_func_name = "comp4_2"
G_path = "G_with_params_" + comp_func_name + ".gpkl"

# %%
with open(os.path.join(exp_dir,"instance.pkl"),'r') as fi:
    lda = pickle.load(fi)
with open(os.path.join(nx_dir,G_path),'r') as fi:
    G = pickle.load(fi)
with open(os.path.join(exp_dir_new,"doc2vec.pkl"),'rb') as fi:
    doc2vec_vectors = pickle.load(fi)

# %%
edges = G.edge
edges
# Out:
# {0: {11: {'weight': 0.35491573767099976},
#   12: {'weight': 0.73905340895447713},
#   13: {'weight': 0.86799707748927746},
#   14: {'weight': 0.67233278811315134},
#   16: {'weight': 0.47164812128681638},
#   17: {'weight': 0.7810720628495238},
#   18: {'weight': 0.78297359570848668},
#   19: {'weight': 0.7727786796108117},
#   20: {'weight': 0.37158674768559441},
#   21: {'weight': 0.92355050127466465},
#   22: {'weight': 0.75208237908875919},
#   24: {'weight': 0.35513119284848693},
#   25: {'weight': 0.65264089322309926},
#   26: {'weight': 0.70191312769499892},
#   27: {'weight': 0.91901443081352086}},
#  2: {28: {'weight': 0.44736480413431307},
#   29: {'weight': 0.444568041417777},
#   31: {'weight': 0.59245830711492231}},
#  3: {9: {'weight': 0.77711656171729204},
#   32: {'weight': 0.53546233976420021},
#   34: {'weight': 0.66010867321432587},
#   35: {'weight': 0.5363941852381976},
#   36: {'weight': 0.54802897651210725},
#   38: {'weight': 0.67788170138369364},
#   40: {'weight': 0.47039789450603375},
#   41: {'weight': 0.74924675576533306},
#   42: {'weight': 0.56888794358649475},
#   43: {'weight': 0.661416849790324},
#   44: {'weight': 0.68359657434345245},
#   47: {'weight': 0.59837435784478554},
#   48: {'weight': 0.44159719069952358},
#   49: {'weight': 0.62472440805286078},
#   50: {'weight': 0.5057411524224803}},
#  4: {31: {'weight': 0.6696426629347817}, 52: {'weight': 0.40832300018028966}},
#  5: {28: {'weight': 0.45987577762109932},
#   29: {'weight': 0.45742926934404132},
#   31: {'weight': 0.54395357848294446},
#   53: {'weight': 0.35885403739423227}},
#  6: {31: {'weight': 0.64264083054652532}, 52: {'weight': 0.3412175051614823}},
#  7: {31: {'weight': 0.66782710585975369}},
#  9: {28: {'weight': 0.8978074109808637},
#   29: {'weight': 0.89050738879291025},
#   31: {'weight': 0.6288449972937995},
#   53: {'weight': 0.65677272668775288}},
#  10: {31: {'weight': 0.6325688424896504}},
#  11: {},
#  12: {26: {'weight': 0.31294542723220964}},
#  13: {},
#  14: {26: {'weight': 0.26768822748342913}},
#  16: {},
#  17: {0: {'weight': 0.7810720628495238}, 26: {'weight': 0.32794873698102722}},
#  18: {0: {'weight': 0.78297359570848668}, 26: {'weight': 0.35225918216730534}},
#  19: {0: {'weight': 0.7727786796108117},
#   5: {'weight': 0.48486010170105598},
#   26: {'weight': 0.33271292943620723}},
#  20: {},
#  21: {26: {'weight': 0.81952149539086405}},
#  22: {},
#  24: {},
#  25: {},
#  26: {0: {'weight': 0.70191312769499892}, 21: {'weight': 0.81952149539086405}},
#  27: {11: {'weight': 0.45842813517561282},
#   16: {'weight': 0.59258083144432627},
#   20: {'weight': 0.48064661941426923}},
#  28: {9: {'weight': 0.8978074109808637},
#   29: {'weight': 0.99562063598024786},
#   34: {'weight': 0.96792169639880055},
#   35: {'weight': 0.61858220847211143},
#   36: {'weight': 0.8437089601895843},
#   42: {'weight': 0.67596359734954981},
#   44: {'weight': 0.87103865905429678},
#   47: {'weight': 0.92908559600889562},
#   50: {'weight': 0.58526445087174961}},
#  29: {9: {'weight': 0.89050738879291025},
#   32: {'weight': 0.80187126550404564},
#   34: {'weight': 0.94702867386508471},
#   35: {'weight': 0.61535205579454499},
#   36: {'weight': 0.80227858576852384},
#   38: {'weight': 0.87775445749437409},
#   40: {'weight': 0.67840471728930829},
#   41: {'weight': 0.84323887322254598},
#   42: {'weight': 0.67721387442731873},
#   43: {'weight': 0.80817727078797941},
#   44: {'weight': 0.86287590393606772},
#   47: {'weight': 0.8954581590908548},
#   48: {'weight': 0.66183863483348315},
#   50: {'weight': 0.5809731212612097}},
#  31: {},
#  32: {29: {'weight': 0.80187126550404564}},
#  34: {28: {'weight': 0.96792169639880055},
#   29: {'weight': 0.94702867386508471},
#   53: {'weight': 0.82060005919539003}},
#  35: {29: {'weight': 0.61535205579454499}},
#  36: {},
#  38: {28: {'weight': 0.8738868152307615}, 29: {'weight': 0.87775445749437409}},
#  40: {28: {'weight': 0.72380748281557428},
#   29: {'weight': 0.67840471728930829}},
#  41: {9: {'weight': 0.70078964815561495},
#   29: {'weight': 0.84323887322254598},
#   34: {'weight': 0.76198177043233151},
#   35: {'weight': 0.56520935227258662},
#   36: {'weight': 0.59752840980033439},
#   42: {'weight': 0.63113962439985838},
#   44: {'weight': 0.76358405702129051},
#   47: {'weight': 0.6938003140907808}},
#  42: {28: {'weight': 0.67596359734954981},
#   29: {'weight': 0.67721387442731873}},
#  43: {28: {'weight': 0.8023421296137544}, 29: {'weight': 0.80817727078797941}},
#  44: {28: {'weight': 0.87103865905429678},
#   29: {'weight': 0.86287590393606772},
#   53: {'weight': 0.78006376833357183}},
#  47: {28: {'weight': 0.92908559600889562}},
#  48: {29: {'weight': 0.66183863483348315}},
#  49: {9: {'weight': 0.58843529359902502},
#   29: {'weight': 0.61764573621758279},
#   34: {'weight': 0.53403322661035457},
#   35: {'weight': 0.47362099942859215},
#   36: {'weight': 0.4748859206969423},
#   42: {'weight': 0.4882711480157691},
#   44: {'weight': 0.58452921330236129},
#   47: {'weight': 0.50125836131313406}},
#  50: {},
#  52: {},
#  53: {9: {'weight': 0.65677272668775288},
#   34: {'weight': 0.82060005919539003},
#   35: {'weight': 0.54470180878332808},
#   36: {'weight': 0.59584480574957932},
#   42: {'weight': 0.83331645817037747},
#   44: {'weight': 0.78006376833357183},
#   47: {'weight': 0.73571096261398949}}}

# %%
for node_no,link_node_nos in edges.items():
    p_dst = doc2vec_vectors[node_no]
    """類似度による重みの算出"""
    for link_node_no in link_node_nos.keys():
        q_dst = doc2vec_vectors[link_node_no]
        weight = cos_sim(p_dst,q_dst)
        edges[node_no][link_node_no]["weight"] = weight

# %%
edges
# Out:
# {0: {11: {'weight': 0.52774781},
#   12: {'weight': 0.51228356},
#   13: {'weight': 0.39132142},
#   14: {'weight': 0.49526924},
#   16: {'weight': 0.46215996},
#   17: {'weight': 0.5651291},
#   18: {'weight': 0.50176561},
#   19: {'weight': 0.49557868},
#   20: {'weight': 0.48542392},
#   21: {'weight': 0.26971427},
#   22: {'weight': 0.40360728},
#   24: {'weight': 0.53056872},
#   25: {'weight': 0.47460645},
#   26: {'weight': 0.48607972},
#   27: {'weight': 0.48736471}},
#  2: {28: {'weight': 0.59756637},
#   29: {'weight': 0.66564733},
#   31: {'weight': 0.44527915}},
#  3: {9: {'weight': 0.64192981},
#   32: {'weight': 0.43719265},
#   34: {'weight': 0.64199376},
#   35: {'weight': 0.4416568},
#   36: {'weight': 0.51677215},
#   38: {'weight': 0.53382462},
#   40: {'weight': 0.64261132},
#   41: {'weight': 0.65991849},
#   42: {'weight': 0.68318331},
#   43: {'weight': 0.55273813},
#   44: {'weight': 0.63351357},
#   47: {'weight': 0.49099377},
#   48: {'weight': 0.5701111},
#   49: {'weight': 0.5509308},
#   50: {'weight': 0.49354166}},
#  4: {31: {'weight': 0.52418143}, 52: {'weight': 0.48457694}},
#  5: {28: {'weight': 0.4727726},
#   29: {'weight': 0.55064929},
#   31: {'weight': 0.38540623},
#   53: {'weight': 0.47840273}},
#  6: {31: {'weight': 0.42262092}, 52: {'weight': 0.54465818}},
#  7: {31: {'weight': 0.46496034}},
#  9: {28: {'weight': 0.6827355},
#   29: {'weight': 0.73058295},
#   31: {'weight': 0.52640414},
#   53: {'weight': 0.57709056}},
#  10: {31: {'weight': 0.63020593}},
#  11: {},
#  12: {26: {'weight': 0.49900258}},
#  13: {},
#  14: {26: {'weight': 0.44761315}},
#  16: {},
#  17: {0: {'weight': 0.5651291}, 26: {'weight': 0.44841355}},
#  18: {0: {'weight': 0.50176561}, 26: {'weight': 0.46931005}},
#  19: {0: {'weight': 0.49557868},
#   5: {'weight': 0.65039188},
#   26: {'weight': 0.49523935}},
#  20: {},
#  21: {26: {'weight': 0.39902246}},
#  22: {},
#  24: {},
#  25: {},
#  26: {0: {'weight': 0.48607972}, 21: {'weight': 0.39902246}},
#  27: {11: {'weight': 0.56362069},
#   16: {'weight': 0.45889843},
#   20: {'weight': 0.68109584}},
#  28: {9: {'weight': 0.6827355},
#   29: {'weight': 0.7130205},
#   34: {'weight': 0.66740727},
#   35: {'weight': 0.45152199},
#   36: {'weight': 0.61336339},
#   42: {'weight': 0.63124663},
#   44: {'weight': 0.6492126},
#   47: {'weight': 0.61938137},
#   50: {'weight': 0.56179166}},
#  29: {9: {'weight': 0.73058295},
#   32: {'weight': 0.5279485},
#   34: {'weight': 0.67174709},
#   35: {'weight': 0.50696105},
#   36: {'weight': 0.65257502},
#   38: {'weight': 0.63545465},
#   40: {'weight': 0.68289471},
#   41: {'weight': 0.63438338},
#   42: {'weight': 0.72555673},
#   43: {'weight': 0.66517532},
#   44: {'weight': 0.69035435},
#   47: {'weight': 0.59402579},
#   48: {'weight': 0.61709344},
#   50: {'weight': 0.57376891}},
#  31: {},
#  32: {29: {'weight': 0.5279485}},
#  34: {28: {'weight': 0.66740727},
#   29: {'weight': 0.67174709},
#   53: {'weight': 0.63384813}},
#  35: {29: {'weight': 0.50696105}},
#  36: {},
#  38: {28: {'weight': 0.56885988}, 29: {'weight': 0.63545465}},
#  40: {28: {'weight': 0.69123286}, 29: {'weight': 0.68289471}},
#  41: {9: {'weight': 0.51641858},
#   29: {'weight': 0.63438338},
#   34: {'weight': 0.57863724},
#   35: {'weight': 0.40916234},
#   36: {'weight': 0.4860813},
#   42: {'weight': 0.52220982},
#   44: {'weight': 0.54434448},
#   47: {'weight': 0.56255335}},
#  42: {28: {'weight': 0.63124663}, 29: {'weight': 0.72555673}},
#  43: {28: {'weight': 0.61069047}, 29: {'weight': 0.66517532}},
#  44: {28: {'weight': 0.6492126},
#   29: {'weight': 0.69035435},
#   53: {'weight': 0.54874355}},
#  47: {28: {'weight': 0.61938137}},
#  48: {29: {'weight': 0.61709344}},
#  49: {9: {'weight': 0.4980582},
#   29: {'weight': 0.56611615},
#   34: {'weight': 0.48674965},
#   35: {'weight': 0.2786884},
#   36: {'weight': 0.36470789},
#   42: {'weight': 0.60315812},
#   44: {'weight': 0.45716596},
#   47: {'weight': 0.46652287}},
#  50: {},
#  52: {},
#  53: {9: {'weight': 0.57709056},
#   34: {'weight': 0.63384813},
#   35: {'weight': 0.48521525},
#   36: {'weight': 0.6550042},
#   42: {'weight': 0.63847166},
#   44: {'weight': 0.54874355},
#   47: {'weight': 0.62166554}}}

# %%
DEFAULT_WEIGHT = 0.5

# %%
G.node.keys()
# Out:
# [0,
#  2,
#  3,
#  4,
#  5,
#  6,
#  7,
#  9,
#  10,
#  11,
#  12,
#  13,
#  14,
#  16,
#  17,
#  18,
#  19,
#  20,
#  21,
#  22,
#  24,
#  25,
#  26,
#  27,
#  28,
#  29,
#  31,
#  32,
#  34,
#  35,
#  36,
#  38,
#  40,
#  41,
#  42,
#  43,
#  44,
#  47,
#  48,
#  49,
#  50,
#  52,
#  53]

# %%
nodes = G.node
nodes
# Out:
# {0: {'a_score': 8.561922690394718e-16,
#   'color': '#00A0C1',
#   'from_hosts': {u'time-space.kddi.com': 3, u'www.kddi.com': 1},
#   'h_score': 4.999029713779984e-15,
#   'to_hosts': {u'onlineshop.au.com': 1,
#    u'star.auone.jp': 1,
#    u'time-space.kddi.com': 5,
#    u'wowma.jp': 1,
#    u'www.kddi.com': 7},
#   'topic': 5},
#  2: {'a_score': 0.0,
#   'color': '#0086D1',
#   'from_hosts': {},
#   'h_score': 0.014396614118132653,
#   'to_hosts': {u'aiphone.co.jp': 1,
#    u'itunes.apple.com': 1,
#    u'support.apple.com': 1},
#   'topic': 6},
#  3: {'a_score': 0.0,
#   'color': '#00479D',
#   'from_hosts': {},
#   'h_score': 0.1667736070325817,
#   'to_hosts': {u'discussionsjapan.apple.com': 2, u'www.apple.com': 13},
#   'topic': 7},
#  4: {'a_score': 0.0,
#   'color': '#FCC800',
#   'from_hosts': {},
#   'h_score': 0.0010197900420815058,
#   'to_hosts': {u'aiphone.co.jp': 1, u'softbankmobile.co.jp': 1},
#   'topic': 1},
#  5: {'a_score': 2.4098746315893005e-16,
#   'color': '#0086D1',
#   'from_hosts': {u'time-space.kddi.com': 1},
#   'h_score': 0.015590000563581237,
#   'to_hosts': {u'aiphone.co.jp': 1,
#    u'itunes.apple.com': 1,
#    u'support.apple.com': 2},
#   'topic': 6},
#  6: {'a_score': 0.0,
#   'color': '#0086D1',
#   'from_hosts': {},
#   'h_score': 0.0010197900420815058,
#   'to_hosts': {u'aiphone.co.jp': 1, u'softbankmobile.co.jp': 1},
#   'topic': 6},
#  7: {'a_score': 0.0,
#   'color': '#0086D1',
#   'from_hosts': {},
#   'h_score': 0.0009794925873430089,
#   'to_hosts': {u'aiphone.co.jp': 1},
#   'topic': 6},
#  9: {'a_score': 0.09017112348992978,
#   'color': '#009B6B',
#   'from_hosts': {u'discussionsjapan.apple.com': 2,
#    u'itunes.apple.com': 1,
#    u'support.apple.com': 3},
#   'h_score': 0.015590000563581237,
#   'to_hosts': {u'aiphone.co.jp': 1,
#    u'itunes.apple.com': 1,
#    u'support.apple.com': 2},
#   'topic': 4},
#  10: {'a_score': 0.0,
#   'color': '#00479D',
#   'from_hosts': {},
#   'h_score': 0.0009794925873430089,
#   'to_hosts': {u'aiphone.co.jp': 1},
#   'topic': 7},
#  11: {'a_score': 2.030512028143646e-15,
#   'color': '#22AC38',
#   'from_hosts': {u'star.auone.jp': 1, u'www.au.com': 1},
#   'h_score': 0.0,
#   'to_hosts': {},
#   'topic': 3},
#  12: {'a_score': 1.6612669884892521e-15,
#   'color': '#00479D',
#   'from_hosts': {u'www.au.com': 1},
#   'h_score': 5.250416388603686e-16,
#   'to_hosts': {u'www.kddi.com': 1},
#   'topic': 7},
#  13: {'a_score': 1.6612669884892521e-15,
#   'color': '#22AC38',
#   'from_hosts': {u'www.au.com': 1},
#   'h_score': 0.0,
#   'to_hosts': {},
#   'topic': 3},
#  14: {'a_score': 1.6612669884892521e-15,
#   'color': '#00479D',
#   'from_hosts': {u'www.au.com': 1},
#   'h_score': 5.250416388603686e-16,
#   'to_hosts': {u'www.kddi.com': 1},
#   'topic': 7},
#  16: {'a_score': 2.030512028143646e-15,
#   'color': '#22AC38',
#   'from_hosts': {u'star.auone.jp': 1, u'www.au.com': 1},
#   'h_score': 0.0,
#   'to_hosts': {},
#   'topic': 3},
#  17: {'a_score': 1.6612669884892521e-15,
#   'color': '#00479D',
#   'from_hosts': {u'www.au.com': 1},
#   'h_score': 6.812144522075647e-16,
#   'to_hosts': {u'www.au.com': 1, u'www.kddi.com': 1},
#   'topic': 7},
#  18: {'a_score': 1.6612669884892521e-15,
#   'color': '#00479D',
#   'from_hosts': {u'www.au.com': 1},
#   'h_score': 6.812144522075647e-16,
#   'to_hosts': {u'www.au.com': 1, u'www.kddi.com': 1},
#   'topic': 7},
#  19: {'a_score': 1.6612669884892521e-15,
#   'color': '#00479D',
#   'from_hosts': {u'www.au.com': 1},
#   'h_score': 7.25171506556065e-16,
#   'to_hosts': {u'www.apple.com': 1, u'www.au.com': 1, u'www.kddi.com': 1},
#   'topic': 7},
#  20: {'a_score': 2.030512028143646e-15,
#   'color': '#22AC38',
#   'from_hosts': {u'star.auone.jp': 1, u'www.au.com': 1},
#   'h_score': 0.0,
#   'to_hosts': {},
#   'topic': 3},
#  21: {'a_score': 1.8237122990435647e-15,
#   'color': '#00A0C1',
#   'from_hosts': {u'www.au.com': 1, u'www.kddi.com': 1},
#   'h_score': 5.250416388603686e-16,
#   'to_hosts': {u'www.kddi.com': 1},
#   'topic': 5},
#  22: {'a_score': 1.6612669884892521e-15,
#   'color': '#00A0C1',
#   'from_hosts': {u'www.au.com': 1},
#   'h_score': 0.0,
#   'to_hosts': {},
#   'topic': 5},
#  24: {'a_score': 1.6612669884892521e-15,
#   'color': '#22AC38',
#   'from_hosts': {u'www.au.com': 1},
#   'h_score': 0.0,
#   'to_hosts': {},
#   'topic': 3},
#  25: {'a_score': 1.6612669884892521e-15,
#   'color': '#00479D',
#   'from_hosts': {u'www.au.com': 1},
#   'h_score': 0.0,
#   'to_hosts': {},
#   'topic': 7},
#  26: {'a_score': 2.878456131264493e-15,
#   'color': '#00A0C1',
#   'from_hosts': {u'onlineshop.au.com': 1,
#    u'time-space.kddi.com': 5,
#    u'www.au.com': 1},
#   'h_score': 4.888250583821091e-16,
#   'to_hosts': {u'onlineshop.au.com': 1, u'www.au.com': 1},
#   'topic': 5},
#  27: {'a_score': 1.6612669884892521e-15,
#   'color': '#00A0C1',
#   'from_hosts': {u'www.au.com': 1},
#   'h_score': 1.1111199695587126e-15,
#   'to_hosts': {u'www.kddi.com': 3},
#   'topic': 5},
#  28: {'a_score': 0.014195735062605293,
#   'color': '#CFDB00',
#   'from_hosts': {u'www.apple.com': 10},
#   'h_score': 0.13515612612755556,
#   'to_hosts': {u'support.apple.com': 1, u'www.apple.com': 8},
#   'topic': 2},
#  29: {'a_score': 0.05936147045360937,
#   'color': '#CFDB00',
#   'from_hosts': {u'discussionsjapan.apple.com': 2,
#    u'itunes.apple.com': 1,
#    u'www.apple.com': 12},
#   'h_score': 0.16347854065286888,
#   'to_hosts': {u'discussionsjapan.apple.com': 1, u'www.apple.com': 13},
#   'topic': 2},
#  31: {'a_score': 0.005369910184048116,
#   'color': '#22AC38',
#   'from_hosts': {u'nttdocomo.co.jp': 2,
#    u'www.apple.com': 3,
#    u'www.softbank.jp': 2},
#   'h_score': 0.0,
#   'to_hosts': {},
#   'topic': 3},
#  32: {'a_score': 0.035772423599053714,
#   'color': '#009B6B',
#   'from_hosts': {u'support.apple.com': 2},
#   'h_score': 0.01082776402030236,
#   'to_hosts': {u'support.apple.com': 1},
#   'topic': 4},
#  34: {'a_score': 0.09017112348992978,
#   'color': '#CFDB00',
#   'from_hosts': {u'discussionsjapan.apple.com': 2,
#    u'itunes.apple.com': 1,
#    u'support.apple.com': 3},
#   'h_score': 0.014610507976238226,
#   'to_hosts': {u'itunes.apple.com': 1, u'support.apple.com': 2},
#   'topic': 2},
#  35: {'a_score': 0.09017112348992978,
#   'color': '#22AC38',
#   'from_hosts': {u'discussionsjapan.apple.com': 2,
#    u'itunes.apple.com': 1,
#    u'support.apple.com': 3},
#   'h_score': 0.01082776402030236,
#   'to_hosts': {u'support.apple.com': 1},
#   'topic': 3},
#  36: {'a_score': 0.09017112348992978,
#   'color': '#009B6B',
#   'from_hosts': {u'discussionsjapan.apple.com': 2,
#    u'itunes.apple.com': 1,
#    u'support.apple.com': 3},
#   'h_score': 0.0,
#   'to_hosts': {},
#   'topic': 4},
#  38: {'a_score': 0.035772423599053714,
#   'color': '#CFDB00',
#   'from_hosts': {u'support.apple.com': 2},
#   'h_score': 0.013417121530789645,
#   'to_hosts': {u'itunes.apple.com': 1, u'support.apple.com': 1},
#   'topic': 2},
#  40: {'a_score': 0.035772423599053714,
#   'color': '#009B6B',
#   'from_hosts': {u'support.apple.com': 2},
#   'h_score': 0.013417121530789645,
#   'to_hosts': {u'itunes.apple.com': 1, u'support.apple.com': 1},
#   'topic': 4},
#  41: {'a_score': 0.035772423599053714,
#   'color': '#CFDB00',
#   'from_hosts': {u'support.apple.com': 2},
#   'h_score': 0.12596071935203743,
#   'to_hosts': {u'support.apple.com': 1, u'www.apple.com': 7},
#   'topic': 2},
#  42: {'a_score': 0.09017112348992978,
#   'color': '#00A0C1',
#   'from_hosts': {u'discussionsjapan.apple.com': 2,
#    u'itunes.apple.com': 1,
#    u'support.apple.com': 3},
#   'h_score': 0.013417121530789645,
#   'to_hosts': {u'itunes.apple.com': 1, u'support.apple.com': 1},
#   'topic': 5},
#  43: {'a_score': 0.035772423599053714,
#   'color': '#CFDB00',
#   'from_hosts': {u'support.apple.com': 2},
#   'h_score': 0.013417121530789645,
#   'to_hosts': {u'itunes.apple.com': 1, u'support.apple.com': 1},
#   'topic': 2},
#  44: {'a_score': 0.09017112348992978,
#   'color': '#CFDB00',
#   'from_hosts': {u'discussionsjapan.apple.com': 2,
#    u'itunes.apple.com': 1,
#    u'support.apple.com': 3},
#   'h_score': 0.014610507976238226,
#   'to_hosts': {u'itunes.apple.com': 1, u'support.apple.com': 2},
#   'topic': 2},
#  47: {'a_score': 0.09017112348992978,
#   'color': '#CFDB00',
#   'from_hosts': {u'discussionsjapan.apple.com': 2,
#    u'itunes.apple.com': 1,
#    u'support.apple.com': 3},
#   'h_score': 0.0025893575104872823,
#   'to_hosts': {u'itunes.apple.com': 1},
#   'topic': 2},
#  48: {'a_score': 0.035772423599053714,
#   'color': '#009B6B',
#   'from_hosts': {u'support.apple.com': 2},
#   'h_score': 0.01082776402030236,
#   'to_hosts': {u'support.apple.com': 1},
#   'topic': 4},
#  49: {'a_score': 0.01806467015491379,
#   'color': '#EB6100',
#   'from_hosts': {u'support.apple.com': 1},
#   'h_score': 0.12596071935203743,
#   'to_hosts': {u'support.apple.com': 1, u'www.apple.com': 7},
#   'topic': 0},
#  50: {'a_score': 0.05041233504815494,
#   'color': '#22AC38',
#   'from_hosts': {u'itunes.apple.com': 1, u'support.apple.com': 2},
#   'h_score': 0.0,
#   'to_hosts': {},
#   'topic': 3},
#  52: {'a_score': 0.00022092429834356025,
#   'color': '#22AC38',
#   'from_hosts': {u'www.softbank.jp': 2},
#   'h_score': 0.0,
#   'to_hosts': {},
#   'topic': 3},
#  53: {'a_score': 0.006542548774465789,
#   'color': '#CFDB00',
#   'from_hosts': {u'www.apple.com': 4},
#   'h_score': 0.11513295533173508,
#   'to_hosts': {u'www.apple.com': 7},
#   'topic': 2}}

# %%
nodes_lim = len(nodes)
nodes_lim
# Out:
# 43

# %%
all_node_weights = np.ones((nodes_lim,nodes_lim))*DEFAULT_WEIGHT#除算の都合上，自分自身との類似度は1に
all_node_weights
# Out:
# array([[ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#        [ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#        [ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#        ...,
#        [ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#        [ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#        [ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5]])

# %%
doc2vec_vectors[0]
# Out:
# array([ 0.09728539,  0.11681181, -0.06479433,  0.09265144,  0.87168008,
#         0.43172827,  0.28555998, -0.56806374,  0.62399924, -0.21992779,
#         0.87188303, -0.30005711,  0.0418622 , -0.23005079, -0.56084543,
#         0.57285142, -0.90125287,  0.21617565,  0.05607327, -0.81053352,
#         0.20767464, -0.35054114, -0.21507274, -0.25569069,  0.47567216,
#         0.00585597, -0.13244919,  0.65534228,  0.41328353,  0.55006796,
#        -1.1059829 , -0.11195086, -0.87832701,  0.14115958,  0.46623084,
#         1.10152054,  1.25085914, -0.20458646,  0.28048515, -0.11694862,
#        -0.1672235 , -0.52451611,  1.39827645,  0.16238143, -0.1005708 ,
#         0.37373319, -0.97177815,  0.4889718 ,  0.02024215, -0.56501257,
#         0.32596564, -0.77922052,  0.44221625, -0.46073452,  0.63100719,
#         0.49374112,  1.47673082, -0.96417469, -0.33211878,  0.3689599 ,
#        -0.27646905,  0.5929358 , -0.05743116, -1.47552538, -0.46054065,
#        -0.0986493 , -0.54994059, -0.16796967,  1.32938969, -0.32188913,
#         1.03585768,  0.02183768, -0.20465519,  0.55284315,  0.76338661,
#        -0.20831177, -0.96117669, -0.59252024, -0.4897182 , -0.39049867,
#        -0.25818911, -1.84602451,  0.69368571,  0.92825377, -1.05558503,
#        -0.67097425, -0.50708067,  0.44761705,  0.91194558,  0.67077118,
#         0.91933858,  0.11626367,  0.13662584,  0.2371162 ,  0.00733519,
#         0.18538977,  0.5051828 , -0.95424664,  0.84924406,  0.36890656], dtype=float32)

# %%
for i,i_node in enumerate(tqdm(nodes)):
    p_dst = doc2vec_vectors[i_node]
    for j,j_node in enumerate(nodes):
        q_dst = doc2vec_vectors[j_node]
        weight = cos_sim(p_dst,q_dst)
        if weight == 0:
            weight = 0.001
        all_node_weights[i,j] = weight
        weights_list.append(weight)#ヒストグラム作成用
# Out:
# 100%|██████████| 43/43 [00:00<00:00, 380.88it/s]

# %%
all_node_weights
# Out:
# array([[ 1.00000012,  0.52296686,  0.56942439, ...,  0.36583862,
#          0.51425296,  0.47446057],
#        [ 0.52296686,  0.99999994,  0.69503725, ...,  0.38309368,
#          0.56961232,  0.59811914],
#        [ 0.56942439,  0.69503725,  1.        , ...,  0.49354166,
#          0.58852792,  0.64527404],
#        ...,
#        [ 0.36583862,  0.38309368,  0.49354166, ...,  1.        ,
#          0.42683601,  0.49814016],
#        [ 0.51425296,  0.56961232,  0.58852792, ...,  0.42683601,
#          0.99999988,  0.48762593],
#        [ 0.47446057,  0.59811914,  0.64527404, ...,  0.49814016,
#          0.48762593,  1.        ]])

# %%
edges[2][28]
# Out:
# {'weight': 0.59756637}

# %%
cos_sim(doc2vec_vectors[2],doc2vec_vectors[28])
# Out:
# 0.59756637

# %%
all_node_weights[1,24]
# Out:
# 0.59756636619567871

# %%
all_node_weights[24,1]
# Out:
# 0.59756636619567871

# %%
weights_list
# Out:
# [1.0000001,
#  0.52296686,
#  0.56942439,
#  0.5307138,
#  0.41537997,
#  0.4353711,
#  0.4325783,
#  0.49407715,
#  0.4566358,
#  0.52774781,
#  0.51228356,
#  0.39132142,
#  0.49526924,
#  0.46215996,
#  0.5651291,
#  0.50176561,
#  0.49557868,
#  0.48542392,
#  0.26971427,
#  0.40360728,
#  0.53056872,
#  0.47460645,
#  0.48607972,
#  0.48736471,
#  0.48582587,
#  0.53004354,
#  0.56015092,
#  0.31620738,
#  0.61379224,
#  0.37173739,
#  0.43379411,
#  0.30718392,
#  0.50740665,
#  0.61415011,
#  0.41189188,
#  0.34468067,
#  0.43852627,
#  0.57430708,
#  0.48230988,
#  0.51400834,
#  0.36583862,
#  0.51425296,
#  0.47446057,
#  0.52296686,
#  0.99999994,
#  0.69503725,
#  0.59725887,
#  0.5918805,
#  0.89470977,
#  0.87948197,
#  0.66692126,
#  0.47169951,
#  0.40424949,
#  0.64156955,
#  0.38915402,
#  0.40376875,
#  0.3231627,
#  0.52221471,
#  0.59712768,
#  0.70461226,
#  0.3602275,
#  0.35914144,
#  0.47158551,
#  0.25505903,
#  0.48901898,
#  0.54233307,
#  0.44670695,
#  0.59756637,
#  0.66564733,
#  0.44527915,
#  0.3027766,
#  0.64646947,
#  0.33678004,
#  0.47097215,
#  0.51240742,
#  0.55851197,
#  0.52568728,
#  0.57960361,
#  0.62755722,
#  0.74228239,
#  0.41427121,
#  0.4438169,
#  0.45616841,
#  0.38309368,
#  0.56961232,
#  0.59811914,
#  0.56942439,
#  0.69503725,
#  1.0,
#  0.62858778,
#  0.55469733,
#  0.65749866,
#  0.6687904,
#  0.64192981,
#  0.49100903,
#  0.56436831,
#  0.62237096,
#  0.51197451,
#  0.49105993,
#  0.42488497,
#  0.54622334,
#  0.65121657,
#  0.6508947,
#  0.43749198,
#  0.33338889,
#  0.4290747,
#  0.41243488,
#  0.47459677,
#  0.53704017,
#  0.52215707,
#  0.65261585,
#  0.6883474,
#  0.50636709,
#  0.43719265,
#  0.64199376,
#  0.4416568,
#  0.51677215,
#  0.53382462,
#  0.64261132,
#  0.65991849,
#  0.68318331,
#  0.55273813,
#  0.63351357,
#  0.49099377,
#  0.5701111,
#  0.5509308,
#  0.49354166,
#  0.58852792,
#  0.64527404,
#  0.5307138,
#  0.59725887,
#  0.62858778,
#  1.0000001,
#  0.41088411,
#  0.61637467,
#  0.61734164,
#  0.6334247,
#  0.65523916,
#  0.46882805,
#  0.60440958,
#  0.45286155,
#  0.47674006,
#  0.36496499,
#  0.6028682,
#  0.61530721,
#  0.6148001,
#  0.53092879,
#  0.41294143,
#  0.41933423,
#  0.32545114,
#  0.43448988,
#  0.47884429,
#  0.56409281,
#  0.67661065,
#  0.64149195,
#  0.52418143,
#  0.4178519,
#  0.58063871,
#  0.43943796,
#  0.55993366,
#  0.49909428,
#  0.64846414,
#  0.54803634,
#  0.58262032,
#  0.46010059,
#  0.56130868,
#  0.63246506,
#  0.54786897,
#  0.53801519,
#  0.56811911,
#  0.48457694,
#  0.63016397,
#  0.41537997,
#  0.5918805,
#  0.55469733,
#  0.41088411,
#  1.0,
#  0.60831708,
#  0.59227353,
#  0.44492546,
#  0.39893666,
#  0.30821714,
#  0.59546393,
#  0.32857293,
#  0.36944953,
#  0.20535648,
#  0.47533244,
#  0.6037643,
#  0.65039188,
#  0.36597738,
#  0.35624737,
#  0.35152736,
#  0.17184362,
#  0.53526819,
#  0.43062422,
#  0.34949937,
#  0.4727726,
#  0.55064929,
#  0.38540623,
#  0.27642679,
#  0.44748905,
#  0.39833164,
#  0.44252127,
#  0.37266198,
#  0.48961112,
#  0.3612923,
#  0.56704205,
#  0.39270896,
#  0.45784414,
#  0.31708851,
#  0.33049476,
#  0.37134546,
#  0.39099467,
#  0.41821584,
#  0.47840273,
#  0.4353711,
#  0.89470977,
#  0.65749866,
#  0.61637467,
#  0.60831708,
#  0.99999994,
#  0.92199254,
#  0.64902949,
#  0.4650543,
#  0.35677907,
#  0.63561273,
#  0.34444085,
#  0.42746794,
#  0.30178082,
#  0.48853523,
#  0.56193447,
#  0.7127105,
#  0.37509879,
#  0.3719998,
#  0.4948009,
#  0.189733,
#  0.44074476,
#  0.48567402,
#  0.41347504,
#  0.57790661,
#  0.65469205,
#  0.42262092,
#  0.38113463,
#  0.59681839,
#  0.38946402,
#  0.47572744,
#  0.51520288,
#  0.58715677,
#  0.4985944,
#  0.60860181,
#  0.63770276,
#  0.74794304,
#  0.40370134,
#  0.41728497,
#  0.42974928,
#  0.42771187,
#  0.54465818,
#  0.61238819,
#  0.4325783,
#  0.87948197,
#  0.6687904,
#  0.61734164,
#  0.59227353,
#  0.92199254,
#  1.0,
#  0.6734857,
#  0.48667294,
#  0.44772816,
#  0.63526052,
#  0.42123932,
#  0.44365221,
#  0.36300263,
#  0.53010786,
#  0.59607977,
#  0.70981115,
#  0.43333179,
#  0.33114812,
#  0.54866564,
#  0.2444271,
#  0.42148259,
#  0.54552293,
#  0.50010574,
#  0.6399045,
#  0.71265715,
#  0.46496034,
#  0.45187563,
#  0.62471604,
#  0.44186226,
#  0.56209636,
#  0.59144962,
#  0.61659634,
#  0.53053707,
#  0.60530573,
#  0.69509804,
#  0.77218032,
#  0.47225446,
#  0.50546139,
#  0.42583364,
#  0.52059013,
#  0.5707593,
#  0.6542871,
#  0.49407715,
#  0.66692126,
#  0.64192981,
#  0.6334247,
#  0.44492546,
#  0.64902949,
#  0.6734857,
#  1.0,
#  0.60299498,
#  0.4868784,
#  0.53537029,
#  0.44116747,
#  0.47481957,
#  0.3577193,
#  0.55239618,
#  0.54008186,
#  0.58513671,
#  0.44572774,
#  0.40714931,
#  0.42307618,
#  0.36580315,
#  0.45330128,
#  0.44120434,
#  0.50631976,
#  0.6827355,
#  0.73058295,
#  0.52640414,
#  0.50445628,
#  0.70707029,
#  0.43170565,
#  0.50593889,
#  0.65920734,
#  0.57915771,
#  0.51641858,
#  0.67821717,
#  0.64227861,
#  0.68335986,
#  0.52330685,
#  0.54678041,
#  0.4980582,
#  0.47983688,
#  0.45075721,
#  0.57709056,
#  0.4566358,
#  0.47169951,
#  0.49100903,
#  0.65523916,
#  0.39893666,
#  0.4650543,
#  0.48667294,
#  0.60299498,
#  1.0,
#  0.37554044,
#  0.56173736,
#  0.46009475,
#  0.47730061,
#  0.30493966,
#  0.62550449,
#  0.51114583,
#  0.48129117,
#  0.53916126,
#  0.59785122,
#  0.48606285,
#  0.29148251,
#  0.56363475,
#  0.51838297,
#  0.6557824,
#  0.60083097,
#  0.6228084,
#  0.63020593,
#  0.47778365,
#  0.47523141,
#  0.39428037,
#  0.55304569,
#  0.40415776,
#  0.56738389,
#  0.52591372,
#  0.54215783,
#  0.3556065,
#  0.41801387,
#  0.59010971,
#  0.44176871,
#  0.64240414,
#  0.42317858,
#  0.55970025,
#  0.57688141,
#  0.52774781,
#  0.40424949,
#  0.56436831,
#  0.46882805,
#  0.30821714,
#  0.35677907,
#  0.44772816,
#  0.4868784,
#  0.37554044,
#  1.0,
#  0.3385295,
#  0.50367218,
#  0.36605322,
#  0.72663134,
#  0.39300075,
#  0.39517325,
#  0.35812485,
#  0.70421588,
#  0.21360099,
#  0.49180853,
#  0.66738784,
#  0.21307163,
#  0.44183663,
#  0.56362069,
#  0.5222711,
#  0.46641055,
#  0.5101794,
#  0.42906055,
#  0.42317516,
#  0.63060915,
#  0.5761047,
#  0.3337087,
#  0.40616405,
#  0.49720001,
#  0.50025159,
#  0.48332715,
#  0.4100849,
#  0.5167551,
#  0.47757986,
#  0.39398643,
#  0.70343715,
#  0.42106828,
#  0.45577347,
#  0.51228356,
#  0.64156955,
#  0.62237096,
#  0.60440958,
#  0.59546393,
#  0.63561273,
#  0.63526052,
#  0.53537029,
#  0.56173736,
#  0.3385295,
#  0.99999994,
#  0.3961184,
#  0.65501773,
#  0.19724175,
#  0.75932747,
#  0.81117404,
#  0.82448196,
#  0.43347111,
#  0.40460438,
#  0.43887588,
#  0.199809,
#  0.51160657,
#  0.49900258,
#  0.53385514,
#  0.6007002,
#  0.61070246,
#  0.48429152,
#  0.31379667,
#  0.46469319,
#  0.26760176,
#  0.45627195,
#  0.46618122,
#  0.55573738,
#  0.51217258,
#  0.57348502,
#  0.47307855,
#  0.49712899,
#  0.51891655,
#  0.40905502,
#  0.53284866,
#  0.34712425,
#  0.43692595,
#  0.57592052,
#  0.39132142,
#  0.38915402,
#  0.51197451,
#  0.45286155,
#  0.32857293,
#  0.34444085,
#  0.42123932,
#  0.44116747,
#  0.46009475,
#  0.50367218,
#  0.3961184,
#  1.0000001,
#  0.38282505,
#  0.41436982,
#  0.43298689,
#  0.40396953,
#  0.33688235,
#  0.49095151,
#  0.32480189,
#  0.53394377,
#  0.50316316,
#  0.3174324,
#  0.7017746,
#  0.55399925,
#  0.45532182,
#  0.42903024,
#  0.48276159,
#  0.38810501,
#  0.43223718,
#  0.33975339,
#  0.42953345,
#  0.48610097,
#  0.45241863,
#  0.55060953,
#  0.44062528,
#  0.45335037,
#  0.34869066,
#  0.3714934,
#  0.35481197,
#  0.34591585,
#  0.45615348,
#  0.42574748,
#  0.44641814,
#  0.49526924,
#  0.40376875,
#  0.49105993,
#  0.47674006,
#  0.36944953,
#  0.42746794,
#  0.44365221,
#  0.47481957,
#  0.47730061,
#  0.36605322,
#  0.65501773,
#  0.38282505,
#  1.0000001,
#  0.2215417,
#  0.62341636,
#  0.56254989,
#  0.58969426,
#  0.38082412,
#  0.32285568,
#  0.40873241,
#  0.24389467,
#  0.37032169,
#  0.44761315,
#  0.4548893,
#  0.59673601,
#  0.46989435,
#  0.48042983,
#  0.24930559,
#  0.43572772,
#  0.19072753,
#  0.30252624,
#  0.30836111,
#  0.38391382,
#  0.58913058,
#  0.4907023,
#  0.28788045,
#  0.43203849,
#  0.41926393,
#  0.28132051,
#  0.62210685,
#  0.23099948,
#  0.23484264,
#  0.43358278,
#  0.46215996,
#  0.3231627,
#  0.42488497,
#  0.36496499,
#  0.20535648,
#  0.30178082,
#  0.36300263,
#  0.3577193,
#  0.30493966,
#  0.72663134,
#  0.19724175,
#  0.41436982,
#  0.2215417,
#  1.0000001,
#  0.26292127,
#  0.22607078,
#  0.24092406,
#  0.55499595,
#  0.21327414,
#  0.33675963,
#  0.64421695,
#  0.1341137,
#  0.28984943,
#  0.45889843,
#  0.37545344,
#  0.42322823,
#  0.4762637,
#  0.5224964,
#  0.35593405,
#  0.60863698,
#  0.59583533,
#  0.2508828,
#  0.34287268,
#  0.46768302,
#  0.35942423,
#  0.38712683,
#  0.39994824,
#  0.47619379,
#  0.54079896,
#  0.25910813,
#  0.62316149,
#  0.45334196,
#  0.30832052,
#  0.5651291,
#  0.52221471,
#  0.54622334,
#  0.6028682,
#  0.47533244,
#  0.48853523,
#  0.53010786,
#  0.55239618,
#  0.62550449,
#  0.39300075,
#  0.75932747,
#  0.43298689,
#  0.62341636,
#  0.26292127,
#  0.99999988,
#  0.65943182,
#  0.62561101,
#  0.567644,
#  0.47471991,
#  0.39029232,
#  0.23888607,
#  0.57266241,
#  0.44841355,
#  0.64591259,
#  0.60192877,
#  0.68382037,
#  0.55464011,
#  0.33394957,
#  0.48192906,
#  0.40523326,
#  0.50424886,
#  0.44025645,
#  0.62599117,
#  0.50398362,
#  0.54497802,
#  0.38792992,
#  0.45074722,
#  0.50313932,
#  0.42153236,
#  0.55061442,
#  0.3990244,
#  0.42203447,
#  0.56663948,
#  0.50176561,
#  0.59712768,
#  0.65121657,
#  0.61530721,
#  0.6037643,
#  0.56193447,
#  0.59607977,
#  0.54008186,
#  0.51114583,
#  0.39517325,
#  0.81117404,
#  0.40396953,
#  0.56254989,
#  0.22607078,
#  0.65943182,
#  1.0,
#  0.80463696,
#  0.40551868,
#  0.27719375,
#  0.42494729,
#  0.25873736,
#  0.47065088,
#  0.46931005,
#  0.52716029,
#  0.66523921,
#  0.64317632,
#  0.50411969,
#  0.30423057,
#  0.50082564,
#  0.25689942,
#  0.47907272,
#  0.49803177,
#  0.54296279,
#  0.49506965,
#  0.60636514,
#  0.51605582,
#  0.52581865,
#  0.53279197,
#  0.43088728,
#  0.52998954,
#  0.39725068,
#  0.46427205,
#  0.58418447,
#  0.49557868,
#  0.70461226,
#  0.6508947,
#  0.6148001,
#  0.65039188,
#  0.7127105,
#  0.70981115,
#  0.58513671,
#  0.48129117,
#  0.35812485,
#  0.82448196,
#  0.33688235,
#  0.58969426,
#  0.24092406,
#  0.62561101,
#  0.80463696,
#  1.0,
#  0.38636541,
#  0.35775515,
#  0.45084515,
#  0.23801592,
#  0.49331388,
#  0.49523935,
#  0.48010933,
#  0.63813996,
#  0.60876119,
#  0.45389327,
#  0.36229497,
#  0.56607616,
#  0.31558222,
#  0.47880855,
#  0.48037839,
#  0.57168299,
#  0.44966859,
#  0.55946469,
#  0.55252302,
#  0.58577919,
#  0.49138817,
#  0.44827026,
#  0.48451698,
#  0.37122741,
#  0.46950206,
#  0.60220873,
#  0.48542392,
#  0.3602275,
#  0.43749198,
#  0.53092879,
#  0.36597738,
#  0.37509879,
#  0.43333179,
#  0.44572774,
#  0.53916126,
#  0.70421588,
#  0.43347111,
#  0.49095151,
#  0.38082412,
#  0.55499595,
#  0.567644,
#  0.40551868,
#  0.38636541,
#  1.0,
#  0.41897288,
#  0.50836086,
#  0.55939776,
#  0.28211987,
#  0.40060785,
#  0.68109584,
#  0.5174135,
#  0.53819823,
#  0.64300764,
#  0.44649008,
#  0.34930882,
#  0.62954348,
#  0.64164299,
#  0.34521988,
#  0.54226434,
#  0.4224087,
#  0.52146745,
#  0.39680734,
#  0.33578923,
#  0.5317052,
#  0.50167161,
#  0.39691246,
#  0.71229416,
#  0.48261431,
#  0.48843366,
#  0.26971427,
#  0.35914144,
#  0.33338889,
#  0.41294143,
#  0.35624737,
#  0.3719998,
#  0.33114812,
#  0.40714931,
#  0.59785122,
#  0.21360099,
#  0.40460438,
#  0.32480189,
#  0.32285568,
#  0.21327414,
#  0.47471991,
#  0.27719375,
#  0.35775515,
#  0.41897288,
#  0.99999988,
#  0.35683241,
#  0.14299074,
#  0.47443998,
#  0.39902246,
#  0.44011021,
#  0.33046955,
#  0.46220452,
#  0.43475369,
#  0.29184675,
#  0.28219441,
#  0.27015585,
#  0.32237631,
#  0.250788,
#  0.37557891,
#  0.34894788,
#  0.41234857,
#  0.20504403,
#  0.30221584,
#  0.24084222,
#  0.18663068,
#  0.49118105,
#  0.22637711,
#  0.36438382,
#  0.38637036,
#  0.40360728,
#  0.47158551,
#  0.4290747,
#  0.41933423,
#  0.35152736,
#  0.4948009,
#  0.54866564,
#  0.42307618,
#  0.48606285,
#  0.49180853,
#  0.43887588,
#  0.53394377,
#  0.40873241,
#  0.33675963,
#  0.39029232,
#  0.42494729,
#  0.45084515,
#  0.50836086,
#  0.35683241,
#  1.0,
#  0.33287174,
#  0.38413402,
#  0.6741311,
#  0.57470012,
#  0.46005532,
#  0.44579664,
#  0.55841053,
#  0.3415809,
#  0.31704825,
#  0.27926791,
#  0.36377925,
#  0.31789714,
#  0.45284384,
#  0.46375835,
#  0.37748557,
#  0.44045523,
#  0.39736041,
#  0.35496697,
#  0.264052,
#  0.30876917,
#  0.38823399,
#  0.53958452,
#  0.40974399,
#  0.53056872,
#  0.25505903,
#  0.41243488,
#  0.32545114,
#  0.17184362,
#  0.189733,
#  0.2444271,
#  0.36580315,
#  0.29148251,
#  0.66738784,
#  0.199809,
#  0.50316316,
#  0.24389467,
#  0.64421695,
#  0.23888607,
#  0.25873736,
#  0.23801592,
#  0.55939776,
#  0.14299074,
#  0.33287174,
#  0.99999988,
#  0.20791891,
#  0.37660709,
#  0.38888159,
#  0.38352549,
#  0.35215437,
#  0.53364807,
#  0.3724106,
#  0.41128603,
#  0.41185847,
#  0.47148001,
#  0.25555801,
#  0.38540238,
#  0.45374429,
#  0.36859897,
#  0.39673284,
#  0.31183761,
#  0.39899105,
#  0.53371316,
#  0.3223722,
#  0.52162778,
#  0.41031057,
#  0.25315863,
#  0.47460645,
#  0.48901898,
#  0.47459677,
#  0.43448988,
#  0.53526819,
#  0.44074476,
#  0.42148259,
#  0.45330128,
#  0.56363475,
#  0.21307163,
#  0.51160657,
#  0.3174324,
#  0.37032169,
#  0.1341137,
#  0.57266241,
#  0.47065088,
#  0.49331388,
#  0.28211987,
#  0.47443998,
#  0.38413402,
#  0.20791891,
#  1.0000001,
#  0.52863979,
#  0.37989321,
#  0.4013595,
#  0.53636622,
#  0.49667287,
#  0.14682753,
#  0.35298279,
#  0.20118544,
#  0.23926459,
#  0.24893469,
#  0.48956415,
#  0.38269079,
#  0.44366133,
#  0.22493756,
#  0.30108467,
#  0.20966157,
#  0.27294785,
#  0.57847226,
#  0.13749859,
#  0.47614217,
#  0.41617763,
#  0.48607972,
#  0.54233307,
#  0.53704017,
#  0.47884429,
#  0.43062422,
#  0.48567402,
#  0.54552293,
#  0.44120434,
#  0.51838297,
#  0.44183663,
#  0.49900258,
#  0.7017746,
#  0.44761315,
#  0.28984943,
#  0.44841355,
#  0.46931005,
#  0.49523935,
#  0.40060785,
#  0.39902246,
#  0.6741311,
#  0.37660709,
#  0.52863979,
#  1.0000001,
#  0.5627408,
#  0.49656895,
#  0.47784668,
#  0.50214005,
#  0.21298321,
#  0.50656331,
#  0.23782642,
#  0.33991739,
#  0.47628158,
#  0.5150888,
#  0.59294677,
#  0.48603848,
#  0.42935601,
#  0.39483333,
#  0.35879567,
#  0.28521925,
#  0.53970963,
#  0.30852237,
#  0.54830736,
#  0.49837989,
#  0.48736471,
#  0.44670695,
#  0.52215707,
#  0.56409281,
#  0.34949937,
#  0.41347504,
#  0.50010574,
#  0.50631976,
#  0.6557824,
#  0.56362069,
#  0.53385514,
#  ...]

# %%
len(weights_list)
# Out:
# 1849

# %%
with open(os.path.join(nx_dir_new,"G_with_params_cos_sim.gpkl"),'w') as fo:
    pickle.dump(G,fo)
with open(os.path.join(nx_dir_new,"all_node_weights_cos_sim.gpkl"),'w') as fo:
    pickle.dump(all_node_weights,fo)

# %%
"""weight（全ノード間の距離）のヒストグラム作成"""
fig_w = plt.figure()
ax = fig_w.add_subplot(1,1,1)
weights_array = np.array(weights_list,dtype=np.float)
ax.hist(weights_array,bins=100)
plt.text(0.5, 0.9, "max="+"{0:.3f}".format(weights_array.max()), transform=ax.transAxes)
plt.text(0.5, 0.85, "min="+"{0:.3g}".format(weights_array.min()), transform=ax.transAxes)
fig_w.show()
fig_w.savefig(os.path.join(nx_dir_new,"cos_sim_hist.png"))
# Out:
# /home/yukichika/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
weights_list.count(1)
# Out:
# 22
