# %%
import urllib.request
import urllib.error
import lxml.html

# %%
src_url = "http://search.yahoo.co.jp/search?p=%E3%83%A9%E3%83%BC%E3%83%A1%E3%83%B3&ei=UTF-8&fl=2&dups=1&b=1"
collected_urls = []

# %%
req = urllib.request.Request(src_url)
req

# %%
response = urllib.request.urlopen(req)
response

# %%
html = response.read()
html
# Out:
# b'<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd"><html><head><meta http-equiv="content-type" content="text/html; charset=UTF-8"><title>\xe3\x80\x8c\xe3\x83\xa9\xe3\x83\xbc\xe3\x83\xa1\xe3\x83\xb3\xe3\x80\x8d\xe3\x81\xae\xe6\xa4\x9c\xe7\xb4\xa2\xe7\xb5\x90\xe6\x9e\x9c - Yahoo!\xe6\xa4\x9c\xe7\xb4\xa2</title><meta name="description" content="Yahoo!"><meta name="robots" content="nofollow,noarchive"><meta http-equiv="Content-Script-Type" content="text/javascript"><meta http-equiv="Content-Style-Type" content="text/css"><meta property="fb:app_id" content="235345649908455"><meta property="og:locale" content="ja_JP"><meta property="og:site_name" content="Yahoo!\xe6\xa4\x9c\xe7\
# ...

# %%
urls = []

# %%
dom = lxml.html.fromstring(html)
dom
# Out:
# <Element html at 0x7f4d18105d18>

# %%
dom.xpath('//div[@id = "WS2m"]//h3/a')
# Out:
# []

# %%
dom.xpath('//*[@id="WS2m"]')
# Out:
# []

# %%
dom.xpath('/html/body//div[@id="WS2m"]')
# Out:
# []
